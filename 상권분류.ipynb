# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('store_info.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5136\1892032302.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('store_info.csv')

# %%
df
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0037544      영자's곱창  NaN        I2       음식      I201
# 1       MA0101202210A0097916       호텔클로이  NaN        I1       숙박      I101
# 2       MA0101202210A0096343   나라차중계태권도장  NaN        P1       교육      P106
# 3       MA0101202210A0093845       이상한스냅  NaN        M1    과학·기술      M113
# 4       MA010120220805430767         토끼정  NaN        I2       음식      I201
# ...                      ...         ...  ...       ...      ...       ...
# 473757  MA0101202303A0082673        놀아보자  NaN        M1    과학·기술      M107
# 473758  MA0101202303A0010399    멕시칸라이브그릴  송파점        I2       음식      I204
# 473759  MA0101202303A0018222        이프모텔  NaN        I1       숙박      I101
# 473760  MA0101202303A0039667  강남고양이분양냥블리  NaN        G2       소매      G220
# 473761  MA0101202303A0046496   어린왕자노래연습장  NaN        R1   예술·스포츠      R104
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473762 entries, 0 to 473761
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     473762 non-null  object
#  1   상호명        473762 non-null  object
#  2   지점명        3962 non-null    object
#  3   상권업종대분류코드  473762 non-null  object
#  4   상권업종대분류명   473762 non-null  object
#  5   상권업종중분류코드  473762 non-null  object
#  6   상권업종중분류명   473762 non-null  object
#  7   상권업종소분류코드  473762 non-null  object
#  8   상권업종소분류명   473762 non-null  object
#  9   표준산업분류코드   473706 non-null  object
#  10  표준산업분류명    473706 non-null  object
#  11  시도코드       473762 non-null  int64
#  12  시도명        473762 non-null  object
#  13  시군구코드      473762 non-null  int64
#  14  시군구명       473762 non-null  object
#  15  행정동코드      473762 non-null  int64
#  16  행정동명       473762 non-null  object
#  17  법정동코드      473762 non-null  int64
#  18  법정동명       473762 non-null  object
# ...

# %%
df = df[['상호명','상권업종대분류명','상권업종중분류명','상권업종소분류명','표준산업분류명','시군구명','행정동명','법정동명','지번주소','도로명','건물명','도로명주소','신우편번호','층정보','경도','위도']]

# %%
df
# Out:
#                상호명 상권업종대분류명    상권업종중분류명       상권업종소분류명            표준산업분류명  \
# 0           영자's곱창       음식          한식       곱창 전골/구이         한식 일반 음식점업
# 1            호텔클로이       숙박       일반 숙박          여관/모텔                여관업
# 2        나라차중계태권도장       교육       기타 교육       태권도/무술학원      태권도 및 무술 교육기관
# 3            이상한스냅    과학·기술       사진 촬영          사진촬영업             사진 처리업
# 4              토끼정       음식          한식         백반/한정식         한식 일반 음식점업
# ...            ...      ...         ...            ...                ...
# 473757        놀아보자    과학·기술   본사·경영 컨설팅        경영 컨설팅업            경영 컨설팅업
# 473758    멕시칸라이브그릴       음식         서양식            경양식           서양식 음식점업
# 473759        이프모텔       숙박       일반 숙박          여관/모텔                여관업
# 473760  강남고양이분양냥블리       소매  애완동물·용품 소매  애완동물/애완용품 소매업  애완용 동물 및 관련용품 소매업
# 473761   어린왕자노래연습장   예술·스포츠      유원지·오락            노래방         노래 연습장 운영업
#
#        시군구명  행정동명   법정동명                  지번주소                  도로명       건물명  \
# ...

# %%
df['상권업종대분류명'].value_counts()
# Out:
# 음식         132764
# 소매         103674
# 과학·기술       85306
# 수리·개인       47367
# 교육          25421
# 부동산         24978
# 시설관리·임대     21285
# 예술·스포츠      19321
# 보건의료         7485
# 숙박           6161
# Name: 상권업종대분류명, dtype: int64

# %%
df_food = df[df['상권업종대분류명']=='음식']
df_food = df_food.reset_index(drop=True)
df_food
# Out:
#               상호명 상권업종대분류명 상권업종중분류명       상권업종소분류명          표준산업분류명 시군구명  \
# 0          영자's곱창       음식       한식       곱창 전골/구이       한식 일반 음식점업  광진구
# 1             토끼정       음식       한식         백반/한정식       한식 일반 음식점업  강서구
# 2             가배차       음식       한식         백반/한정식       한식 일반 음식점업  송파구
# 3        비에이치씨항동점       음식    기타 간이             치킨           치킨 전문점  구로구
# 4             카페숲       음식    비알코올              카페           커피 전문점  금천구
# ...           ...      ...      ...            ...              ...  ...
# 132759        은행골       음식       일식        일식 회/초밥          일식 음식점업  성북구
# 132760  냠냠족발&보쌈마포       음식    기타 간이  그 외 기타 간이 음식점  간이 음식 포장 판매 전문점  마포구
# 132761      개편한카페       음식    비알코올              카페           커피 전문점  광진구
# 132762       26카페       음식    비알코올              카페           커피 전문점  강북구
# 132763   멕시칸라이브그릴       음식      서양식            경양식         서양식 음식점업  송파구
#
#         행정동명    법정동명                  지번주소                 도로명  \
# ...

# %%
df_food['상권업종중분류명'].value_counts()
# Out:
# 한식         45753
# 기타 간이      27554
# 비알코올       21841
# 주점         17690
# 서양식         6035
# 일식          5979
# 중식          5178
# 동남아시아       1547
# 구내식당·뷔페     1187
# Name: 상권업종중분류명, dtype: int64

# %%
df_food['상권업종소분류명'].value_counts()
# Out:
# 카페               21841
# 백반/한정식           21328
# 요리 주점            11553
# 김밥/만두/분식          8088
# 돼지고기 구이/찜         7568
# 치킨                5605
# 빵/도넛              5560
# 경양식               5478
# 일식 회/초밥           5256
# 중국집               4463
# 국/탕/찌개류           4065
# 피자                3678
# 일반 유흥 주점          3217
# 국수/칼국수            2814
# 생맥주 전문            2813
# 횟집                2281
# 해산물 구이/찜          1691
# 그 외 기타 간이 음식점     1535
# 베트남식 전문           1437
# 곱창 전골/구이          1360
# 닭/오리고기 구이/찜       1346
# 족발/보쌈             1212
# 떡/한과              1180
# 버거                1171
# 구내식당              1025
# 소고기 구이/찜           954
# 마라탕/훠궈             715
# 냉면/밀면              559
# 일식 면 요리            495
# 파스타/스테이크           461
# 아이스크림/빙수           375
# 토스트/샌드위치/샐러드       362
# 기타 한식 음식점          309
# 전/부침개              191
# 일식 카레/돈가스/덮밥       182
# 뷔페                 162
# 기타 동남아식 전문         110
# 무도 유흥 주점           107
# 패밀리레스토랑             76
# 복 요리 전문             75
# ...

# %%
df_dessert = df[df['상권업종소분류명'].isin(['카페','빵/도넛','아이스크림/빙수'])].reset_index(drop=True)
df_dessert = df_dessert[['상호명','도로명주소','위도','경도']]
df_dessert
# Out:
#            상호명                    도로명주소         위도          경도
# 0          카페숲    서울특별시 금천구 시흥대로40길 129  37.446689  126.909939
# 1       이가네꽈배기    서울특별시 금천구 시흥대로144길 26  37.473384  126.900846
# 2        카페활력소         서울특별시 송파구 법원로 96  37.484021  127.120954
# 3          올도우  서울특별시 서대문구 통일로39길 22-25  37.588327  126.942887
# 4      매머드커피외대     서울특별시 동대문구 천장산로7길 16  37.598493  127.056962
# ...        ...                      ...        ...         ...
# 27771     러셀도넛     서울특별시 강동구 양재대로89길 60  37.527320  127.132325
# 27772    이디야논현     서울특별시 강남구 논현로131길 28  37.514074  127.028094
# 27773  아몬드앤아만데     서울특별시 도봉구 덕릉로63가길 61  37.642602  127.037311
# 27774    개편한카페     서울특별시 광진구 긴고랑로 151-1  37.558760  127.091859
# 27775     26카페      서울특별시 강북구 한천로170길 7  37.648070  127.016356
#
# [27776 rows x 4 columns]

# %%
df_dessert.to_csv('dessert.csv')

# %%
df_maratang= df[df['상권업종소분류명'].isin(['마라탕/훠궈'])].reset_index(drop=True)
df_maratang = df_maratang[['상호명','도로명주소','위도','경도']]
df_maratang
# Out:
#          상호명                 도로명주소         위도          경도
# 0    해룡마라룽샤2    서울특별시 중구 을지로41길 28  37.567003  127.006647
# 1       마라지존  서울특별시 강남구 봉은사로30길 73  37.502939  127.037105
# 2     마라홀릭엔씨      서울특별시 송파구 충민로 66  37.477608  127.124941
# 3     룽푸청마라탕  서울특별시 구로구 디지털로33길 48  37.487246  126.894492
# 4       순풍훠궈    서울특별시 금천구 시흥대로 392  37.468450  126.898296
# ..       ...                   ...        ...         ...
# 710     소림마라   서울특별시 동작구 사당로16길 85  37.479995  126.971585
# 711   찐하오마라탕   서울특별시 은평구 불광로 113-1  37.617032  126.932671
# 712    삼미마라탕     서울특별시 관악구 청림2길 36  37.486869  126.958080
# 713     마라캡틴    서울특별시 중랑구 봉화산로 217  37.607761  127.096791
# 714   패밀리마라탕    서울특별시 구로구 경인로59길 8  37.506379  126.883409
#
# [715 rows x 4 columns]

# %%
df_maratang.to_csv('maratang.csv')

# %%
df_bar = df[df['상권업종중분류명'].isin(['주점'])].reset_index(drop=True)
df_bar = df_bar[['상호명','도로명주소','위도','경도']]
df_bar
# Out:
#                상호명                      도로명주소         위도          경도
# 0              카리브         서울특별시 종로구 종로11길 13  37.570915  126.985550
# 1        식감이야기양재역점  서울특별시 서초구 남부순환로350길 19-26  37.484158  127.036804
# 2          대치노래바하트          서울특별시 강남구 삼성로 231  37.497814  127.060966
# 3      맥주창고오라고노량진점         서울특별시 동작구 노량진로 158  37.513420  126.943526
# 4            압구정4층       서울특별시 강남구 선릉로157길 33  37.526284  127.037032
# ...            ...                        ...        ...         ...
# 17685          1포차    서울특별시 성북구 동소문로20길 29-15  37.591539  127.017519
# 17686         오래오래     서울특별시 서초구 강남대로8길 16-18  37.467391  127.042490
# 17687       언덕빼기포차      서울특별시 송파구 백제고분로46길 33  37.507285  127.114698
# 17688           오늘         서울특별시 은평구 응암로14길 8  37.590030  126.918122
# 17689          카페라           서울특별시 중구 동호로 249  37.557499  127.007938
#
# [17690 rows x 4 columns]

# %%
df_bar.to_csv('bar.csv')

# %%
df_food
# Out:
#               상호명 상권업종대분류명 상권업종중분류명       상권업종소분류명          표준산업분류명 시군구명  \
# 0          영자's곱창       음식       한식       곱창 전골/구이       한식 일반 음식점업  광진구
# 1             토끼정       음식       한식         백반/한정식       한식 일반 음식점업  강서구
# 2             가배차       음식       한식         백반/한정식       한식 일반 음식점업  송파구
# 3        비에이치씨항동점       음식    기타 간이             치킨           치킨 전문점  구로구
# 4             카페숲       음식    비알코올              카페           커피 전문점  금천구
# ...           ...      ...      ...            ...              ...  ...
# 132759        은행골       음식       일식        일식 회/초밥          일식 음식점업  성북구
# 132760  냠냠족발&보쌈마포       음식    기타 간이  그 외 기타 간이 음식점  간이 음식 포장 판매 전문점  마포구
# 132761      개편한카페       음식    비알코올              카페           커피 전문점  광진구
# 132762       26카페       음식    비알코올              카페           커피 전문점  강북구
# 132763   멕시칸라이브그릴       음식      서양식            경양식         서양식 음식점업  송파구
#
#         행정동명    법정동명                  지번주소                 도로명  \
# ...

# %%
df_filtered_food = df_food.drop(df_food[(df_food['상권업종중분류명'] == '주점') ].index)

# %%
df_filtered_food
# Out:
#               상호명 상권업종대분류명 상권업종중분류명       상권업종소분류명          표준산업분류명 시군구명  \
# 0          영자's곱창       음식       한식       곱창 전골/구이       한식 일반 음식점업  광진구
# 1             토끼정       음식       한식         백반/한정식       한식 일반 음식점업  강서구
# 2             가배차       음식       한식         백반/한정식       한식 일반 음식점업  송파구
# 3        비에이치씨항동점       음식    기타 간이             치킨           치킨 전문점  구로구
# 4             카페숲       음식    비알코올              카페           커피 전문점  금천구
# ...           ...      ...      ...            ...              ...  ...
# 132759        은행골       음식       일식        일식 회/초밥          일식 음식점업  성북구
# 132760  냠냠족발&보쌈마포       음식    기타 간이  그 외 기타 간이 음식점  간이 음식 포장 판매 전문점  마포구
# 132761      개편한카페       음식    비알코올              카페           커피 전문점  광진구
# 132762       26카페       음식    비알코올              카페           커피 전문점  강북구
# 132763   멕시칸라이브그릴       음식      서양식            경양식         서양식 음식점업  송파구
#
#         행정동명    법정동명                  지번주소                 도로명  \
# ...

# %%
df_filtered_food = df_filtered_food.drop(df_filtered_food[(df_filtered_food['상권업종소분류명'].isin(['아이스크림/빙수', '빵/도넛', '카페']))].index)

# %%
df_filtered_food
# Out:
#               상호명 상권업종대분류명 상권업종중분류명       상권업종소분류명                  표준산업분류명  \
# 0          영자's곱창       음식       한식       곱창 전골/구이               한식 일반 음식점업
# 1             토끼정       음식       한식         백반/한정식               한식 일반 음식점업
# 2             가배차       음식       한식         백반/한정식               한식 일반 음식점업
# 3        비에이치씨항동점       음식    기타 간이             치킨                   치킨 전문점
# 5           샐러드점보       음식    기타 간이             피자  피자, 햄버거, 샌드위치 및 유사 음식점업
# ...           ...      ...      ...            ...                      ...
# 132757     베트남쌀국수       음식    동남아시아        베트남식 전문              기타 외국식 음식점업
# 132758       달빛호떡       음식    기타 간이  그 외 기타 간이 음식점          간이 음식 포장 판매 전문점
# 132759        은행골       음식       일식        일식 회/초밥                  일식 음식점업
# 132760  냠냠족발&보쌈마포       음식    기타 간이  그 외 기타 간이 음식점          간이 음식 포장 판매 전문점
# 132763   멕시칸라이브그릴       음식      서양식            경양식                 서양식 음식점업
#
# ...

# %%
df_filtered_food['상권업종소분류명'].value_counts()
# Out:
# 백반/한정식           21328
# 김밥/만두/분식          8088
# 돼지고기 구이/찜         7568
# 치킨                5605
# 경양식               5478
# 일식 회/초밥           5256
# 중국집               4463
# 국/탕/찌개류           4065
# 피자                3678
# 국수/칼국수            2814
# 횟집                2281
# 해산물 구이/찜          1691
# 그 외 기타 간이 음식점     1535
# 베트남식 전문           1437
# 곱창 전골/구이          1360
# 닭/오리고기 구이/찜       1346
# 족발/보쌈             1212
# 떡/한과              1180
# 버거                1171
# 구내식당              1025
# 소고기 구이/찜           954
# 마라탕/훠궈             715
# 냉면/밀면              559
# 일식 면 요리            495
# 파스타/스테이크           461
# 토스트/샌드위치/샐러드       362
# 기타 한식 음식점          309
# 전/부침개              191
# 일식 카레/돈가스/덮밥       182
# 뷔페                 162
# 기타 동남아식 전문         110
# 패밀리레스토랑             76
# 복 요리 전문             75
# 기타 일식 음식점           46
# 기타 서양식 음식점          20
# Name: 상권업종소분류명, dtype: int64

# %%
df_filtered_food.to_csv('df_filtered_food.csv')
